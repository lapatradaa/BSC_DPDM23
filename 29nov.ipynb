# %% [markdown]
# <a href="https://colab.research.google.com/github/lapatradaa/BSC_DPDM23/blob/main/29nov.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Load data

# %%
import pandas as pd

# %% [markdown]
#  # Load Excel from Gdrive

# %%
# mounting colab with google drive
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
shopping_data = pd.read_csv('/content/drive/MyDrive/bsc_dpdm23/shopping/bsc_dpdm23_data/customer_shopping_data.csv')

# %%
shopping_data.head()
# Out:
#   invoice_no customer_id  gender  age  category  quantity    price  \
# 0    I138884     C241288  Female   28  Clothing         5  1500.40
# 1    I317333     C111565    Male   21     Shoes         3  1800.51
# 2    I127801     C266599    Male   20  Clothing         1   300.08
# 3    I173702     C988172  Female   66     Shoes         5  3000.85
# 4    I337046     C189076  Female   53     Books         4    60.60
#
#   payment_method invoice_date   shopping_mall
# 0    Credit Card     5/8/2022          Kanyon
# 1     Debit Card   12/12/2021  Forum Istanbul
# 2           Cash    9/11/2021       Metrocity
# 3    Credit Card   16/05/2021    Metropol AVM
# 4           Cash   24/10/2021          Kanyon

# %% [markdown]
# # Basic stats

# %%
shopping_data.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.256321
# std       14.990054      1.413025    941.184567
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %% [markdown]
# #How many payment method?

# %% [markdown]
# #คนอายุมากกว่า 40 มีค่าเฉลี่ยของราคาสินค้าเท่าไหร่

# %%
shopping_data[shopping_data['age'] > 40].describe()
# Out:
#                 age      quantity         price
# count  55167.000000  55167.000000  55167.000000
# mean      54.976743      3.003426    690.853136
# std        8.374926      1.412343    942.539041
# min       41.000000      1.000000      5.230000
# 25%       48.000000      2.000000     45.450000
# 50%       55.000000      3.000000    203.300000
# 75%       62.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %% [markdown]
# # Visualization

# %%
from matplotlib import pyplot as plt

# %% [markdown]
# #Histrogram

# %% [markdown]
# # ดู location

# %%
plt.hist(shopping_data['shopping_mall'])
plt.xticks(rotation='vertical');

# %%
shopping_data.describe()
# Out:
#                 age      quantity         price
# count  99457.000000  99457.000000  99457.000000
# mean      43.427089      3.003429    689.256321
# std       14.990054      1.413025    941.184567
# min       18.000000      1.000000      5.230000
# 25%       30.000000      2.000000     45.450000
# 50%       43.000000      3.000000    203.300000
# 75%       56.000000      4.000000   1200.320000
# max       69.000000      5.000000   5250.000000

# %% [markdown]
# # Distance - Similarity

# %% [markdown]
# # z-score
