# %% [markdown]
# <a href="https://colab.research.google.com/github/lapatradaa/BSC_DPDM23/blob/main/Data_Preprocessing.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
shopping_data = pd.read_csv('/content/drive/MyDrive/bsc_dpdm23/shopping/bsc_dpdm23_data/customer_shopping_data.csv')

# %%
shopping_data
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5  1500.40
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 2        I127801     C266599    Male   20         Clothing         1   300.08
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 1         Debit Card   12/12/2021    Forum Istanbul
# 2               Cash    9/11/2021         Metrocity
# 3        Credit Card   16/05/2021      Metropol AVM
# 4               Cash   24/10/2021            Kanyon
# ...              ...          ...               ...
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul
#
# [99457 rows x 10 columns]

# %% [markdown]
# # ข้อมูลบางส่วนมีค่าตัวแปรบางตัวที่ไม่ทราบค่า (Missing Data)

# %%
shopping_data.isnull().any() # .any > all ทุกค่า
# Out:
# invoice_no        False
# customer_id       False
# gender            False
# age               False
# category          False
# quantity          False
# price             False
# payment_method    False
# invoice_date      False
# shopping_mall     False
# dtype: bool

# %% [markdown]
# ### เราจะลบค่า price ของ records ที่เป็น clothing, cash, metrocity ออก เพื่อจำลอง missing data

# %%
shopping_data[(shopping_data['category']=='Clothing') &
              (shopping_data['payment_method']=='Cash') &
              (shopping_data['shopping_mall']=='Metrocity')].describe()
# Out:
#                age     quantity  price
# count  2284.000000  2284.000000    0.0
# mean     43.657618     2.982049    NaN
# std      14.974270     1.408979    NaN
# min      18.000000     1.000000    NaN
# 25%      30.750000     2.000000    NaN
# 50%      44.000000     3.000000    NaN
# 75%      57.000000     4.000000    NaN
# max      69.000000     5.000000    NaN

# %% [markdown]
# ทำให้ price missing

# %%
willbemissing = shopping_data[(shopping_data['category']=='Clothing') &
              (shopping_data['payment_method']=='Cash') &
              (shopping_data['shopping_mall']=='Metrocity')].describe()

# %%
willbemissing['price']=''

# %%
willbemissing['price']= np.nan

# %%
willbemissing
# Out:
#                age     quantity price
# count  2284.000000  2284.000000
# mean     43.657618     2.982049
# std      14.974270     1.408979
# min      18.000000     1.000000
# 25%      30.750000     2.000000
# 50%      44.000000     3.000000
# 75%      57.000000     4.000000
# max      69.000000     5.000000

# %%
shopping_data[(shopping_data['category']!='Clothing') |
              (shopping_data['payment_method']!='Cash') |
              (shopping_data['shopping_mall']!='Metrocity')]
# Out:
#       invoice_no customer_id  gender  age         category  quantity    price  \
# 0        I138884     C241288  Female   28         Clothing         5      NaN
# 1        I317333     C111565    Male   21            Shoes         3  1800.51
# 3        I173702     C988172  Female   66            Shoes         5  3000.85
# 4        I337046     C189076  Female   53            Books         4    60.60
# 5        I227836     C657758  Female   28         Clothing         5      NaN
# ...          ...         ...     ...  ...              ...       ...      ...
# 99452    I219422     C441542  Female   45         Souvenir         5    58.65
# 99453    I325143     C569580    Male   27  Food & Beverage         2    10.46
# 99454    I824010     C103292    Male   63  Food & Beverage         2    10.46
# 99455    I702964     C800631    Male   56       Technology         4  4200.00
# 99456    I232867     C273973  Female   36         Souvenir         3    35.19
#
#       payment_method invoice_date     shopping_mall
# 0        Credit Card     5/8/2022            Kanyon
# 1         Debit Card   12/12/2021    Forum Istanbul
# 3        Credit Card   16/05/2021      Metropol AVM
# 4               Cash   24/10/2021            Kanyon
# 5        Credit Card   24/05/2022    Forum Istanbul
# ...              ...          ...               ...
# 99452    Credit Card   21/09/2022            Kanyon
# 99453           Cash   22/09/2021    Forum Istanbul
# 99454     Debit Card   28/03/2021         Metrocity
# 99455           Cash   16/03/2021      Istinye Park
# 99456    Credit Card   15/10/2022  Mall of Istanbul
#
# [97173 rows x 10 columns]

# %% [markdown]
# แยกส่วน data ที่ไม่ missing ออกมา

# %%
nomissing =shopping_data[(shopping_data['category']=='Clothing') |
              (shopping_data['payment_method']=='Cash') |
              (shopping_data['shopping_mall']=='Metrocity')]

# %% [markdown]
# จับรวมกัน

# %%
new_shopping_data = pd.concat ([willbemissing,nomissing])
new_shopping_data.shape
# Out:
# (68888, 10)

# %%
new_shopping_data.isnull().any()
# Out:
# age               False
# quantity          False
# price              True
# invoice_no         True
# customer_id        True
# gender             True
# category           True
# payment_method     True
# invoice_date       True
# shopping_mall      True
# dtype: bool

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix

# %% [markdown]
# ### ignore (ลบออกไปก่อน)

# %% [markdown]
# ### QUIZ
# - data หายไปกี่ %
# - mean data รวมหลังจากแก้ missing เท่าไหร่

# %% [markdown]
# # ข้อมูลมีความซ้ำซ้อน (Duplicate Data)

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix

# %% [markdown]
# # ข้อมูลบางตัวในชุดข้อมูลมีลักษณะผิดปกติหรือแตกต่างจากข้อมูลส่วนใหญ่ (Outlier)

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix

# %% [markdown]
# # ค่าตัวแปรบางตัวที่ไม่ถูกต้อง (Erroneous Data)

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix

# %% [markdown]
# # ข้อมูลมีค่าตัวแปรไม่สอดคล้องซึ่งกันและกัน (Inconsistent)

# %% [markdown]
# ## Example

# %% [markdown]
# ## Fix
