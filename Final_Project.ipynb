# %% [markdown]
# <a href="https://colab.research.google.com/github/lapatradaa/BSC_DPDM23/blob/main/Final_Project.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
import pandas as pd
import numpy as np
import os

# %%
df_c = pd.read_excel('/content/drive/MyDrive/DPDM2023/BSCproject/psdexercise.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df_t = pd.read_excel('/content/drive/MyDrive/DPDM2023/BSCproject/psdexercise.xlsx')
# Out:
# /usr/local/lib/python3.10/dist-packages/openpyxl/worksheet/_reader.py:329: UserWarning: Unknown extension is not supported and will be removed
#   warn(msg)

# %%
df_c
# Out:
#          ปี      ภาค      จังหวัด             อำเภอ        ตำบล   เพศ อายุ  \
# 0      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   55
# 1      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   47
# 2      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   45
# 3      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   53
# 4      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   57
# ...     ...      ...          ...               ...         ...   ...  ...
# 20093  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง   48
# 20094  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   29
# 20095  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   40
# 20096  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   35
# 20097  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง   35
#
#                                    การศึกษา     สถานภาพ  \
# ...

# %% [markdown]
# #Prepare and Clean data

# %% [markdown]
# ## เปลี่ยนชื่อ column กิจกรรม_2564 เป็น กิจกรรม

# %%
df_t = df_c.rename(columns={'กิจกรรม_2564': 'กิจกรรม'})

# %%
df_c = df_c.rename(columns={'กิจกรรม_2564': 'กิจกรรม'})

# %%
region_counts = df_c['ภาค'].value_counts()
region_counts
# Out:
# ภาคตะวันออกเฉียงเหนือ    5555
# ภาคกลาง                  5012
# ภาคเหนือ                 4644
# ภาคใต้                   4286
# กรุงเทพมหานคร             601
# Name: ภาค, dtype: int64

# %%
region_counts = df_t['ภาค'].value_counts()
region_counts
# Out:
# ภาคตะวันออกเฉียงเหนือ    5555
# ภาคกลาง                  5012
# ภาคเหนือ                 4644
# ภาคใต้                   4286
# กรุงเทพมหานคร             601
# Name: ภาค, dtype: int64

# %% [markdown]
# เนื่องจากมีภาคกรุงเทพมหานคร ซึ่งไม่ใช่ และต้องเปลี่ยนเป็นภาคกลาง

# %%
df_t.loc[df_t['ภาค'] == 'กรุงเทพมหานคร', 'ภาค'] = 'ภาคกลาง'

# %%
df_c.loc[df_c['ภาค'] == 'กรุงเทพมหานคร', 'ภาค'] = 'ภาคกลาง'

# %%
region_counts = df_c['ภาค'].value_counts()
region_counts
# Out:
# ภาคกลาง                  5613
# ภาคตะวันออกเฉียงเหนือ    5555
# ภาคเหนือ                 4644
# ภาคใต้                   4286
# Name: ภาค, dtype: int64

# %%
region_counts = df_t['ภาค'].value_counts()
region_counts
# Out:
# ภาคกลาง                  5613
# ภาคตะวันออกเฉียงเหนือ    5555
# ภาคเหนือ                 4644
# ภาคใต้                   4286
# Name: ภาค, dtype: int64

# %% [markdown]
# ## drop กิจกรรม
# โดยที่ไม่เอาคนออกกำลังกาย

# %%
df_c = df_c[df_c['กิจกรรม'] != '-']

# %%
df_t = df_t[df_t['กิจกรรม'] != '-']

# %%
# df_c = df_c.drop(df_c[df_c['กิจกรรม'].isin(['-'])].index)

# %%
df_c
# Out:
#          ปี      ภาค      จังหวัด             อำเภอ        ตำบล   เพศ อายุ  \
# 0      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   55
# 3      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   53
# 4      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   57
# 5      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   55
# 7      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   49
# ...     ...      ...          ...               ...         ...   ...  ...
# 20093  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง   48
# 20094  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   29
# 20095  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   40
# 20096  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   35
# 20097  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง   35
#
#                                    การศึกษา     สถานภาพ  \
# ...

# %%
df_a=df_c

# %%
df_a
# Out:
#          ปี      ภาค      จังหวัด             อำเภอ        ตำบล   เพศ อายุ  \
# 0      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   55
# 3      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   53
# 4      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   57
# 5      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   55
# 7      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   49
# ...     ...      ...          ...               ...         ...   ...  ...
# 20093  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง   48
# 20094  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   29
# 20095  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   40
# 20096  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   35
# 20097  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง   35
#
#                                    การศึกษา     สถานภาพ  \
# ...

# %%
excercise = df_t['กิจกรรม']
excercise
# Out:
# 0                           (1)ปั่นจักรยาน
# 3                                  (1)วิ่ง
# 4                           (1)ปั่นจักรยาน
# 5                                  (1)โยคะ
# 7        (1)การออกกำลังกายในการประกอบอาชีพ
#                        ...
# 20093                      (1)เดิน,(2)วิ่ง
# 20094                    (1)เดิน,(2)ฟุตบอล
# 20095            (1)เดิน,(2)วิ่ง,(3)ฟุตบอล
# 20096                              (1)เดิน
# 20097                        (1)วอลเลย์บอล
# Name: กิจกรรม, Length: 15501, dtype: object

# %%
import re
def clean_row(row):
    # ลบเครื่องหมาย
    row = re.sub(r'\([^)]*\)', '', row)
    # ลบเลข
    row = re.sub(r'[0-9]', '', row)
    return row.strip()

# %%
cleaned_rows = [clean_row(row) for row in excercise]

# %%
cleaned_rows_1 = pd.DataFrame({'กิจกรรม': cleaned_rows})

# %%
cleaned_rows_2 = cleaned_rows_1['กิจกรรม'].str.split(',', expand=True)

# %%
df_t['กิจกรรม'] = cleaned_rows_2[0]

# %%
ex = df_t['กิจกรรม'].value_counts()

# %%
df_t['กิจกรรม']
# Out:
# 0                           ปั่นจักรยาน
# 3                                  โยคะ
# 4        การออกกำลังกายในการประกอบอาชีพ
# 5                                  เดิน
# 7                                  เดิน
#                       ...
# 20093                               NaN
# 20094                               NaN
# 20095                               NaN
# 20096                               NaN
# 20097                               NaN
# Name: กิจกรรม, Length: 15501, dtype: object

# %%
df_t.isnull().any()
# Out:
# ปี                   False
# ภาค                  False
# จังหวัด              False
# อำเภอ                False
# ตำบล                 False
# เพศ                  False
# อายุ                 False
# การศึกษา             False
# สถานภาพ              False
# การมีโรคประจำตัว     False
# ประเภทของโรค         False
# อาชีพ                False
# น้ำหนัก              False
# ส่วนสูง              False
# กิจกรรม               True
# ระดับ                False
# นาที/วัน             False
# วัน/สัปดาห์          False
# รวมสรุปกิจกรรม       False
# สถานที่              False
# เวลา                 False
# เวลารวม (ชั่วโมง)    False
# เหตุผล (ออก)         False
# เหตุผล (ไม่ออก)      False
# แรงจูงใจ              True
# ข้อเสนอแนะ           False
# dtype: bool

# %%
ex
# Out:
# เดิน                              5751
# วิ่ง                              2087
# ฟุตบอล                            1035
# ปั่นจักรยาน                        720
# เต้นแอโรบิค                        628
# การออกกำลังกายในการประกอบอาชีพ     441
# ฟุตซอล                             219
# แบดมินตัน                          156
# เซปักตะกร้อ                        112
# โยคะ                               112
# วอลเลย์บอล                         108
# อื่นๆ                              103
# เปตอง                               71
# เพาะกายและฟิตเนส                    57
# เต้นบัสโลบ                          57
# กระโดดเชือก                         48
# บาสเกตบอล                           32
# ฮูลาฮูป                              9
# กายบริหาร                            7
# รำมวยจีน                             6
# สนุกเกอร์                            6
# วู้ดบอล                              6
# ว่ายน้ำ                              5
# มวยไทย                               5
# ...

# %%
set(df_t['กิจกรรม'])
# Out:
# {'-',
#  nan,
#  'กระโดดเชือก',
#  'กอล์ฟ',
#  'กายบริหาร',
#  'การออกกำลังกายในการประกอบอาชีพ',
#  'คาดิโอ',
#  'ซิตอัพ',
#  'บาสเกตบอล',
#  'ปันจักสีลัต',
#  'ปั่นจักรยาน',
#  'ฟุตซอล',
#  'ฟุตบอล',
#  'มวยไทย',
#  'รำมวยจีน',
#  'ลีลาศ',
#  'วอลเลย์บอล',
#  'วิ่ง',
#  'วู้ดบอล',
#  'ว่ายน้ำ',
#  'สนุกเกอร์',
#  'สเก็ตบอร์ด',
#  'อื่นๆ',
#  'ฮูลาฮูป',
#  'เซปักตะกร้อ',
#  'เดิน',
#  'เต้นบัสโลบ',
#  'เต้นแอโรบิค',
#  'เทควันโด',
#  'เทนนิส',
#  'เปตอง',
#  'เพาะกายและฟิตเนส',
#  'เวทเทรนนิ่ง',
#  'แกว่งแขน',
#  'แบดมินตัน',
#  'โยคะ',
#  'ไทเก๊ก',
#  'ไม้พลอง'}

# %% [markdown]
# ## จัดกลุ่มกิจกรรม
# 0 = ลู่วิ่ง,ความเร็วและการต่อสู้
# 1 = ตาข่ายและสนาม

# %%
df_t['กิจกรรม'] = df_t['กิจกรรม'].replace({'เดิน': np.NaN,
                                       'วิ่ง': 0,
                                       'ปั่นจักรยาน': 0,
                                       'กระโดดเชือก':0 ,
                                       'ว่ายน้ำ': 0,
                                       'อื่นๆ': 0,
                                       'เต้นแอโรบิค': 0,
                                       'การออกกำลังกายในการประกอบอาชีพ': 0,
                                       'เพาะกายและฟิตเนส': 0,
                                       'เต้นบัสโลบ': 0,
                                       'ฮูลาฮูป': 0,
                                       'กายบริหาร':0,
                                      'รำมวยจีน': 0,
                                       'มวยไทย': 0,
                                       'แกว่งแขน': 0,
                                       'โยคะ': 0,
                                        'ไทเก๊ก': 0,
                                       'เทควันโด': 0,
                                       'ลีลาศ': 0,
                                       'เวทเทรนนิ่ง': 0,
                                       'คาดิโอ': 0,
                                       'ปันจักสีลัต': 0,
                                      'ซิตอัพ': 0,
                                        'ไทเก๊ก': 0,
                                       'ไม้พลอง': 0,
                                         'ฟุตบอล': 1,
                                         'ฟุตซอล': 1,
                                       'แบตมินตัน': 1,
                                       'เซปักตะกร้อ': 1,
                                       'วอลเลย์บอล': 1,
                                       'เปตอง': 1,
                                       'บาสเกตบอล': 1,
                                       'สนุกเกอร์': 1,
                                       'วู้ดบอล': 1,
                                       'กอล์ฟ': 1,
                                       'เทนนิส': 1,
                                       'สเก็ตบอร์ด': 1,
                                       'แบดมินตัน': 1,
                                        '-': 1,
                                       np.NaN: 1,
                                      })

# %%
set(df_t['กิจกรรม'])
# Out:
# {0.0,
#  1.0,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
#  nan,
# ...

# %%
df_t = df_t.dropna()

# %%
df_t['กิจกรรม'].value_counts()
# Out:
# 1.0    5445
# 0.0    4304
# Name: กิจกรรม, dtype: int64

# %% [markdown]
# ##แก้ภาคกรุงเทพมหานครเป็นภาคกลาง
# - แก้ภาคต่างๆเป็น 1 = ภาคเหนือ,
# 2 = ภาคกลาง,
# 3 = ภาคตะวันออกเฉียงเหนือ,
# 4 = ภาคใต้

# %%
df_t.loc[df_t['ภาค'] == 'ภาคเหนือ', 'ภาค'] = 1
df_t.loc[df_t['ภาค'] == 'ภาคกลาง', 'ภาค'] = 2
df_t.loc[df_t['ภาค'] == 'ภาคตะวันออกเฉียงเหนือ', 'ภาค'] = 3
df_t.loc[df_t['ภาค'] == 'ภาคใต้', 'ภาค'] = 4
df_t
# Out:
#          ปี ภาค      จังหวัด             อำเภอ        ตำบล   เพศ อายุ  \
# 0      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   55
# 3      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   53
# 4      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   57
# 9      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   50
# 11     2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   58
# ...     ...  ..          ...               ...         ...   ...  ...
# 20093  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง   48
# 20094  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   29
# 20095  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   40
# 20096  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   35
# 20097  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง   35
#
#                                    การศึกษา     สถานภาพ  \
# 0                          มัธยมศึกษาตอนต้น  แยกกันอยู่
# ...

# %% [markdown]
# ## จัดกลุ่มอายุ

# %%
df_t['อายุ']
# Out:
# 0        55
# 3        53
# 4        57
# 9        50
# 11       58
#          ..
# 20093    48
# 20094    29
# 20095    40
# 20096    35
# 20097    35
# Name: อายุ, Length: 9749, dtype: object

# %%
df_t['อายุ'] = pd.to_numeric(df_t['อายุ'], errors='coerce').astype('Int64')

# %%
df_t = df_t.dropna()

# %%
df_t.isnull().any()
# Out:
# ปี                   False
# ภาค                  False
# จังหวัด              False
# อำเภอ                False
# ตำบล                 False
# เพศ                  False
# อายุ                 False
# การศึกษา             False
# สถานภาพ              False
# การมีโรคประจำตัว     False
# ประเภทของโรค         False
# อาชีพ                False
# น้ำหนัก              False
# ส่วนสูง              False
# กิจกรรม              False
# ระดับ                False
# นาที/วัน             False
# วัน/สัปดาห์          False
# รวมสรุปกิจกรรม       False
# สถานที่              False
# เวลา                 False
# เวลารวม (ชั่วโมง)    False
# เหตุผล (ออก)         False
# เหตุผล (ไม่ออก)      False
# แรงจูงใจ             False
# ข้อเสนอแนะ           False
# dtype: bool

# %%
from matplotlib import pyplot as plt

# %%
bp_age = plt.boxplot([df_t['อายุ']],
             labels=['Age'])

# %% [markdown]
# ### สร้างฟังก์ชันลบค่า outliers และหาค่า min max q1 q2 q3

# %%
def detail_boxreturn(boxreturn):
    q1 = boxreturn['boxes'][0].get_ydata()[0]
    q2 = boxreturn['medians'][0].get_ydata()[0]
    q3 = boxreturn['boxes'][0].get_ydata()[2]
    minv = min(boxreturn['whiskers'][0].get_ydata())
    maxv = max(boxreturn['whiskers'][1].get_ydata())
    print(f'min = {minv}, max = {maxv}, q1 = {q1}, q2 = {q2}, q3 = {q3}')

# %%
detail_boxreturn(bp_age)
# Out:
# min = 15.0, max = 94.0, q1 = 33.0, q2 = 48.0, q3 = 58.0

# %% [markdown]
# ### แบ่งตาม min max q1 q2 q3 และลบค่าที่มากกว่า 95 ออก
# - กลุ่มที่ 1 = อายุ 15-35 ปี
# - กลุ่มที่ 2 = อายุ 36-49 ปี
# - กลุ่มที่ 3 = อายุ 50-59 ปี
# - กลุ่มที่ 4 = อายุ 60-95 ปี

# %%
df_t = df_t.loc[df_t['อายุ'] <= 95]
df_t
# Out:
#          ปี ภาค      จังหวัด             อำเภอ        ตำบล   เพศ  อายุ  \
# 0      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง    55
# 3      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย    53
# 4      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย    57
# 9      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย    50
# 11     2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย    58
# ...     ...  ..          ...               ...         ...   ...   ...
# 20093  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง    48
# 20094  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย    29
# 20095  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย    40
# 20096  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย    35
# 20097  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง    35
#
#                                    การศึกษา     สถานภาพ  \
# 0                          มัธยมศึกษาตอนต้น  แยกกันอยู่
# ...

# %%
bp_age = plt.boxplot([df_t['อายุ']],
             labels=['Age']) # จะเห็นได้ว่าไม่มีค่า outliers แล้ว

# %% [markdown]
# ###กำหนดช่วงอายุ

# %%
age_1 =df_t[(df_t['อายุ']>15) & (df_t['อายุ']<=35)].count().sum()
age_1
# Out:
# 69524

# %%
df_t.loc[(df_t['อายุ'] >= 15) & (df_t['อายุ'] <= 35), 'อายุ'] = 1
df_t.loc[(df_t['อายุ'] >= 36) & (df_t['อายุ'] <= 49), 'อายุ'] = 2
df_t.loc[(df_t['อายุ'] >= 50) & (df_t['อายุ'] <= 59), 'อายุ'] = 3
df_t.loc[(df_t['อายุ'] >= 60) & (df_t['อายุ'] <= 95), 'อายุ'] = 4
df_t
# Out:
#          ปี ภาค      จังหวัด             อำเภอ        ตำบล   เพศ  อายุ  \
# 0      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง     3
# 3      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# 4      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# 9      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# 11     2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# ...     ...  ..          ...               ...         ...   ...   ...
# 20093  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง     2
# 20094  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย     1
# 20095  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย     2
# 20096  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย     1
# 20097  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง     1
#
#                                    การศึกษา     สถานภาพ  \
# 0                          มัธยมศึกษาตอนต้น  แยกกันอยู่
# ...

# %% [markdown]
# ## จัดกลุ่มสถานภาพ

# %%
status_counts = df_t['สถานภาพ'].value_counts()
status_counts
# Out:
# สมรส                            5813
# โสด                             3075
# หม้าย                            629
# หย่า                             147
# แยกกันอยู่                        80
# อยู่ร่วมกัน                        2
# ไม่ได้แต่งงานแต่มีลูกด้วยกัน       1
# ไม่จดทะเบียนสมรส                   1
# Name: สถานภาพ, dtype: int64

# %%
df_t['สถานภาพ'] = df_t['สถานภาพ'].replace({'หม้าย': 3,'หย่า': 3,'แยกกันอยู่': 3,'สมรส': 2, 'โสด': 1,'อื่น ๆ': 1,'อยู่ร่วมกัน': 1,'ไม่ได้จดทะเบียนสมรส': 1,'ไม่จดทะเบียนสมรส': 1,'สมรสไม่จดทะเบียน': 1,'ไม่ได้แต่งงานแต่มีลูกด้วยกัน': 1,'สมรสไม่ได้จดทะเบียน': 1,'ไม่ได้จดทะเบียน': 1,'มีแฟน': 1})

# %%
status_counts = df_t['สถานภาพ'].value_counts()
status_counts
# Out:
# 2    5813
# 1    3079
# 3     856
# Name: สถานภาพ, dtype: int64

# %% [markdown]
# ##จัดกลุ่มการมีโรคประจำตัว

# %% [markdown]
# แก้ "-" ใน column การมีโรคประจำตัว	เป็นคำว่า "ไม่มี"

# %%
df_t
# Out:
#          ปี ภาค      จังหวัด             อำเภอ        ตำบล   เพศ  อายุ  \
# 0      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง     3
# 3      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# 4      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# 9      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# 11     2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# ...     ...  ..          ...               ...         ...   ...   ...
# 20093  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง     2
# 20094  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย     1
# 20095  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย     2
# 20096  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย     1
# 20097  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง     1
#
#                                    การศึกษา  สถานภาพ         การมีโรคประจำตัว  \
# ...

# %%
no_disease = df_t['การมีโรคประจำตัว'].str.count('-').sum()
no_disease
# Out:
# 0

# %%
df_t.loc[df_t['การมีโรคประจำตัว'].str.contains('-'), 'การมีโรคประจำตัว'] = 'ไม่มี'

# %%
no_disease = df_t['การมีโรคประจำตัว'].str.count('-').sum()
no_disease
# Out:
# 0

# %%
df_t
# Out:
#          ปี ภาค      จังหวัด             อำเภอ        ตำบล   เพศ  อายุ  \
# 0      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง     3
# 3      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# 4      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# 9      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# 11     2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# ...     ...  ..          ...               ...         ...   ...   ...
# 20093  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง     2
# 20094  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย     1
# 20095  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย     2
# 20096  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย     1
# 20097  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง     1
#
#                                    การศึกษา  สถานภาพ         การมีโรคประจำตัว  \
# ...

# %%
# https://www.geeksforgeeks.org/using-apply-in-pandas-lambda-functions-with-multiple-if-statements/

# %%
df_t['การมีโรคประจำตัว'] = df_t['การมีโรคประจำตัว'].apply(lambda x: 0 if x == 'ไม่มี' else 1)

df_t
# Out:
#          ปี ภาค      จังหวัด             อำเภอ        ตำบล   เพศ  อายุ  \
# 0      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง     3
# 3      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# 4      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# 9      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# 11     2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย     3
# ...     ...  ..          ...               ...         ...   ...   ...
# 20093  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง     2
# 20094  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย     1
# 20095  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย     2
# 20096  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย     1
# 20097  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง     1
#
#                                    การศึกษา  สถานภาพ  การมีโรคประจำตัว  ...  \
# ...

# %% [markdown]
# ##จัดกลุ่มเพศ

# %%
df_t['เพศ'] = df_t['เพศ'].replace({'ชาย': 0, 'หญิง': 1})
df_t
# Out:
#          ปี ภาค      จังหวัด             อำเภอ        ตำบล  เพศ  อายุ  \
# 0      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ    1     3
# 3      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ    0     3
# 4      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ    0     3
# 9      2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ    0     3
# 11     2564   2  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ    0     3
# ...     ...  ..          ...               ...         ...  ...   ...
# 20093  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส    1     2
# 20094  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส    0     1
# 20095  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส    0     2
# 20096  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส    0     1
# 20097  2565   4     นราธิวาส             ระแงะ   ตันหยงมัส    1     1
#
#                                    การศึกษา  สถานภาพ  การมีโรคประจำตัว  ...  \
# ...

# %% [markdown]
# ##Desicion Tree

# %% [markdown]
# เลือกเฉพาะคอลัม ที่เราต้องการ

# %%
data_tree = df_t[['เพศ','อายุ','ภาค','การมีโรคประจำตัว','กิจกรรม']]
data_tree
# Out:
#        เพศ  อายุ ภาค  การมีโรคประจำตัว  กิจกรรม
# 0        1     3   2                 0      0.0
# 3        0     3   2                 0      0.0
# 4        0     3   2                 1      0.0
# 9        0     3   2                 0      0.0
# 11       0     3   2                 0      0.0
# ...    ...   ...  ..               ...      ...
# 20093    1     2   4                 0      1.0
# 20094    0     1   4                 0      1.0
# 20095    0     2   4                 0      1.0
# 20096    0     1   4                 0      1.0
# 20097    1     1   4                 0      1.0
#
# [9748 rows x 5 columns]

# %% [markdown]
# เปลี่ยนชื่อคอลัมเป็นภาษาอังกฤษ

# %%
data_tree = data_tree.rename(columns={'กิจกรรม': 'Activity','เพศ':'Gender','อายุ':'Age','ภาค':'Sector','การมีโรคประจำตัว':'Comorbidities'})

# %%
data_tree
# Out:
#        Gender  Age Sector  Comorbidities  Activity
# 0           1    3      2              0       0.0
# 3           0    3      2              0       0.0
# 4           0    3      2              1       0.0
# 9           0    3      2              0       0.0
# 11          0    3      2              0       0.0
# ...       ...  ...    ...            ...       ...
# 20093       1    2      4              0       1.0
# 20094       0    1      4              0       1.0
# 20095       0    2      4              0       1.0
# 20096       0    1      4              0       1.0
# 20097       1    1      4              0       1.0
#
# [9748 rows x 5 columns]

# %%
a = np.random.randint(2, size=len(data_tree))

# %%
a
# Out:
# array([0, 0, 1, ..., 1, 0, 0])

# %%
np.random.seed(seed=1)

# %%
train = data_tree[a == 1]
train.shape
# Out:
# (4792, 5)

# %%
test = data_tree[a == 0]
test.shape
# Out:
# (4956, 5)

# %% [markdown]
# ###import

# %%
from sklearn.tree import DecisionTreeClassifier

# %%
Dtree1 = DecisionTreeClassifier(random_state=0)

# %%
X_train = train.iloc[:,:-1]

# %%
y_train = train.iloc[:,-1]

# %%
Dtree1.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier(random_state=0)

# %%
from sklearn import tree

# %%
tree.plot_tree(Dtree1);

# %% [markdown]
# ###test

# %%
X_test = test.iloc[:,:-1]
y_test = test.iloc[:,-1]

# %%
y_predict = Dtree1.predict(X_test)

# %%
from sklearn.metrics import accuracy_score

# %%
accuracy_score(y_test, y_predict)
# Out:
# 0.6559725585149314

# %%
from sklearn.model_selection import GridSearchCV
from sklearn.tree import DecisionTreeClassifier

# Define parameter grid
param_grid = {
    'max_depth': [2, 3, 4, 5, 6, 7 ],
    'max_leaf_nodes' : [7,9,11,13,15,17],
    'min_samples_split': [ 2, 5, 10],
    'min_samples_leaf': [ 1, 3, 5, 7],
    'max_features': [None, 'sqrt'],
    'criterion': ['gini', 'entropy']
    # ,    # 'random_state' : [1]
}

# Create decision tree classifier
clf = DecisionTreeClassifier()

# Perform grid search
grid_search = GridSearchCV(clf, param_grid, cv=5, scoring='accuracy')
grid_search.fit(X_train, y_train)

# Print the best parameters and score
print("Best parameters:", grid_search.best_params_)
print("Best score:", grid_search.best_score_)
print('-'*50)

# test decison tree
best_param = grid_search.best_params_
Dtree_grid_best = DecisionTreeClassifier(criterion = best_param['criterion'],
                                         max_depth = best_param['max_depth'],
                                         max_features = best_param['max_features'],
                                         max_leaf_nodes = best_param['max_leaf_nodes'],
                                         min_samples_leaf = best_param['min_samples_leaf'],
                                         min_samples_split = best_param['min_samples_split']
                                        #  ,random_state = best_param['random_state']
                                         )

Dtree_grid_best.fit(X_train,y_train)

_, ax = plt.subplots(figsize=(15,10))
tree.plot_tree(Dtree_grid_best);

y_grid_best_predict = Dtree_grid_best.predict(X_test)

acc = accuracy_score(y_test, y_grid_best_predict)

print('-'*50)
print(acc)
print('-'*50)
# Out:
# Best parameters: {'criterion': 'gini', 'max_depth': 3, 'max_features': 'sqrt', 'max_leaf_nodes': 13, 'min_samples_leaf': 7, 'min_samples_split': 10}
# Best score: 0.5734135026700133
# --------------------------------------------------
# --------------------------------------------------
# 0.6573849878934624
# --------------------------------------------------

# %%
accuracy_score(y_test, y_grid_best_predict)
# Out:
# 0.6573849878934624

# %%
data_tree.columns
# Out:
# Index(['Gender', 'Age', 'Sector', 'Comorbidities', 'Activity'], dtype='object')

# %%
features=['Gender','Age','Sector','Comorbidities']

# %%
x=data_tree[features] #features
y=data_tree['Activity'] #label

# %%
from sklearn.model_selection import  train_test_split

# %%
test_size = 0.2
X_train,X_test,y_train,y_test = train_test_split(x,y,test_size = test_size,stratify=y,random_state=7)

# %%
model=DecisionTreeClassifier(criterion='gini')
model.fit(X_train,y_train)
# Out:
# DecisionTreeClassifier()

# %%
X_train.columns
# Out:
# Index(['Gender', 'Age', 'Sector', 'Comorbidities'], dtype='object')

# %%
model.feature_importances_
# Out:
# array([0.01386609, 0.0459867 , 0.91949574, 0.02065147])

# %%
y_train.value_counts()
# Out:
# 1.0    4356
# 0.0    3442
# Name: Activity, dtype: int64

# %%
from io import StringIO
from sklearn.tree import export_graphviz
import pydotplus
from IPython.display import Image

# %%
from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image
import pydotplus

dot_data = StringIO()
export_graphviz(Dtree_grid_best,  out_file=dot_data,
                filled=True, rounded=True,
                special_characters=True,feature_names =features ,class_names=['0','1'])
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
# graph.write_png('diabetes.png')
Image(graph.create_png())

# %%
y_pred = Dtree_grid_best.predict(X_test)

# Evaluation
from sklearn.metrics import accuracy_score, classification_report
print(f'accuracy = {accuracy_score(y_test, y_pred)}')
print(classification_report(y_test, y_pred) )
# Out:
# accuracy = 0.6569230769230769
#               precision    recall  f1-score   support
#
#          0.0       0.72      0.36      0.48       861
#          1.0       0.64      0.89      0.74      1089
#
#     accuracy                           0.66      1950
#    macro avg       0.68      0.63      0.61      1950
# weighted avg       0.68      0.66      0.63      1950

# %%
from sklearn.metrics import confusion_matrix, recall_score, precision_score, f1_score, accuracy_score
cm = confusion_matrix(y_test, y_pred)

dt_Recall = recall_score(y_test, y_pred)
dt_Precision = precision_score(y_test, y_pred)
dt_f1 = f1_score(y_test, y_pred)
dt_accuracy = accuracy_score(y_test, y_pred)

print(cm)
# Out:
# [[311 550]
#  [119 970]]

# %%
dt_Recall
# Out:
# 0.8907254361799817

# %%
dt_Precision
# Out:
# 0.6381578947368421

# %%
dt_f1
# Out:
# 0.7435799156765045

# %%
dt_accuracy
# Out:
# 0.6569230769230769

# %%
from sklearn.metrics import confusion_matrix, recall_score, precision_score, f1_score, accuracy_score
cm = confusion_matrix(y_test, y_pred)

dt_Recall = recall_score(y_test, y_pred)
dt_Precision = precision_score(y_test, y_pred)
dt_f1 = f1_score(y_test, y_pred)
dt_accuracy = accuracy_score(y_test, y_pred)

print(cm)
# Out:
# [[311 550]
#  [119 970]]

# %%
import seaborn as sns

import matplotlib.pyplot as plt
plt.figure(figsize=[13,10])
sns.set(font_scale=3)
sns.heatmap(cm, annot=True, cmap='coolwarm', fmt = 'd')
plt.xlabel('Predicted')
plt.ylabel('True')
plt.show()

# %% [markdown]
# # K-Nearest Neighbor

# %%
from sklearn.neighbors import KNeighborsClassifier
from sklearn.model_selection import GridSearchCV
from sklearn.metrics import f1_score
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Define the parameter grid to search over
parameters_knn = {'n_neighbors': [3, 5, 7, 9, 11],
              'weights': ['uniform', 'distance'],
              'algorithm': ['ball_tree', 'kd_tree', 'brute']}
              # Create the KNN classifier
knn1 = KNeighborsClassifier()

# Create a GridSearchCV object with 10-fold cross-validation
grid_knn1 = GridSearchCV(estimator=knn1, param_grid=parameters_knn, cv=10, n_jobs=-1, verbose=3,scoring = "accuracy")
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# %%time
# Fit the GridSearchCV object to the training data
grid_knn1.fit(X_train, y_train)
# Print the best hyperparameters
print("Best hyperparameters: ", grid_knn1.best_params_)
# Out:
# Fitting 10 folds for each of 30 candidates, totalling 300 fits
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# Best hyperparameters:  {'algorithm': 'brute', 'n_neighbors': 11, 'weights': 'uniform'}
# CPU times: user 918 ms, sys: 146 ms, total: 1.06 s
# Wall time: 15.6 s

# %%
from sklearn.neighbors import KNeighborsClassifier
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
# Instantiate KNN model
knn1 = KNeighborsClassifier(n_neighbors=11, weights='uniform', algorithm='ball_tree')

# Fit the model to the training data
knn1.fit(X_train, y_train)

# Predict the test data
y_pred = knn1.predict(X_test)

#Evaluation
from sklearn.metrics import accuracy_score, classification_report
print(f'accuracy = {accuracy_score(y_test, y_pred)}')
print(classification_report(y_test, y_pred))
# Out:
# accuracy = 0.6241025641025642
#               precision    recall  f1-score   support
#
#          0.0       0.59      0.51      0.55       861
#          1.0       0.65      0.71      0.68      1089
#
#     accuracy                           0.62      1950
#    macro avg       0.62      0.61      0.61      1950
# weighted avg       0.62      0.62      0.62      1950
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# ## เลือกค่า K ที่เหมาะสม

# %% [markdown]
# K =3

# %%
# Instantiate KNN model
knn1 = KNeighborsClassifier(n_neighbors=3, weights='uniform', algorithm='ball_tree')

# Fit the model to the training data
knn1.fit(X_train, y_train)

# Predict the test data
y_pred = knn1.predict(X_test)

#Evaluation
from sklearn.metrics import accuracy_score, classification_report
print(f'accuracy = {accuracy_score(y_test, y_pred)}')
# Out:
# accuracy = 0.5835897435897436
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# K=5

# %%
# Instantiate KNN model
knn1 = KNeighborsClassifier(n_neighbors=5, weights='uniform', algorithm='ball_tree')

# Fit the model to the training data
knn1.fit(X_train, y_train)

# Predict the test data
y_pred = knn1.predict(X_test)

#Evaluation
from sklearn.metrics import accuracy_score, classification_report
print(f'accuracy = {accuracy_score(y_test, y_pred)}')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# accuracy = 0.5897435897435898

# %% [markdown]
# K=7

# %%
# Instantiate KNN model
knn1 = KNeighborsClassifier(n_neighbors=7, weights='uniform', algorithm='ball_tree')

# Fit the model to the training data
knn1.fit(X_train, y_train)

# Predict the test data
y_pred = knn1.predict(X_test)

#Evaluation
from sklearn.metrics import accuracy_score, classification_report
print(f'accuracy = {accuracy_score(y_test, y_pred)}')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# accuracy = 0.6082051282051282

# %% [markdown]
# K=9

# %%
# Instantiate KNN model
knn1 = KNeighborsClassifier(n_neighbors=9, weights='uniform', algorithm='ball_tree')

# Fit the model to the training data
knn1.fit(X_train, y_train)

# Predict the test data
y_pred = knn1.predict(X_test)

#Evaluation
from sklearn.metrics import accuracy_score, classification_report
print(f'accuracy = {accuracy_score(y_test, y_pred)}')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# accuracy = 0.6128205128205129

# %% [markdown]
# K=11

# %%
# Instantiate KNN model
knn1 = KNeighborsClassifier(n_neighbors=11, weights='uniform', algorithm='ball_tree')

# Fit the model to the training data
knn1.fit(X_train, y_train)

# Predict the test data
y_pred = knn1.predict(X_test)

#Evaluation
from sklearn.metrics import accuracy_score, classification_report
print(f'accuracy = {accuracy_score(y_test, y_pred)}')
# Out:
# accuracy = 0.6241025641025642
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# k=13

# %%
# Instantiate KNN model
knn1 = KNeighborsClassifier(n_neighbors=13, weights='uniform', algorithm='ball_tree')

# Fit the model to the training data
knn1.fit(X_train, y_train)

# Predict the test data
y_pred = knn1.predict(X_test)

#Evaluation
from sklearn.metrics import accuracy_score, classification_report
print(f'accuracy = {accuracy_score(y_test, y_pred)}')
print(classification_report(y_test, y_pred))
# Out:
# accuracy = 0.6369230769230769
#               precision    recall  f1-score   support
#
#          0.0       0.62      0.46      0.53       861
#          1.0       0.64      0.78      0.71      1089
#
#     accuracy                           0.64      1950
#    macro avg       0.63      0.62      0.62      1950
# weighted avg       0.63      0.64      0.63      1950
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# K=15

# %%
# Instantiate KNN model
knn1 = KNeighborsClassifier(n_neighbors=15, weights='uniform', algorithm='ball_tree')

# Fit the model to the training data
knn1.fit(X_train, y_train)

# Predict the test data
y_pred = knn1.predict(X_test)

#Evaluation
from sklearn.metrics import accuracy_score, classification_report
print(f'accuracy = {accuracy_score(y_test, y_pred)}')
# Out:
# accuracy = 0.6328205128205128
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# K=17

# %%
# Instantiate KNN model
knn1 = KNeighborsClassifier(n_neighbors=17, weights='uniform', algorithm='ball_tree')

# Fit the model to the training data
knn1.fit(X_train, y_train)

# Predict the test data
y_pred = knn1.predict(X_test)

#Evaluation
from sklearn.metrics import accuracy_score, classification_report
print(f'accuracy = {accuracy_score(y_test, y_pred)}')
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# accuracy = 0.6471794871794871

# %% [markdown]
# เลือกค่า K

# %%
import matplotlib.pyplot as plt

k_values = [3, 5, 7, 9, 11,13,15,17,19]

# accuracies แต่ละค่า K
accuracies = [0.5835, 0.5897, 0.6082, 0.6128, 0.6241 ,0.6369,0.6328,0.6271,0.625]

# พล็อตค่า K และประสิทธิภาพ
plt.plot(k_values, accuracies, marker='o')
plt.title('Accuracy vs. K')
plt.xlabel('K (Number of Neighbors)')
plt.ylabel('Accuracy')
plt.show()
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %% [markdown]
# #Association rules

# %%
df_a
# Out:
#          ปี      ภาค      จังหวัด             อำเภอ        ตำบล   เพศ อายุ  \
# 0      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   55
# 3      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   53
# 4      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   57
# 5      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ  หญิง   55
# 7      2564  ภาคกลาง  สมุทรปราการ  เมืองสมุทรปราการ  สำโรงเหนือ   ชาย   49
# ...     ...      ...          ...               ...         ...   ...  ...
# 20093  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง   48
# 20094  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   29
# 20095  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   40
# 20096  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส   ชาย   35
# 20097  2565   ภาคใต้     นราธิวาส             ระแงะ   ตันหยงมัส  หญิง   35
#
#                                    การศึกษา     สถานภาพ  \
# ...

# %%
import pandas as pd
import os
# !pip install apyori
from apyori import apriori
# Out:
# ...
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for apyori: filename=apyori-1.1.2-py3-none-any.whl size=5955 sha256=aecfb8039db82eb16254439a8a1a27db47e580a02dd43fc0ebd3c2320dd7c10d
#   Stored in directory: /root/.cache/pip/wheels/c4/1a/79/20f55c470a50bb3702a8cb7c94d8ada15573538c7f4baebe2d
# Successfully built apyori
# ...

# %%
associate = df_a[['ปี','ภาค','เพศ','อายุ','กิจกรรม','เหตุผล (ออก)','เวลา']]
associate
# Out:
#          ปี      ภาค   เพศ อายุ                            กิจกรรม  \
# 0      2564  ภาคกลาง  หญิง   55                     (1)ปั่นจักรยาน
# 3      2564  ภาคกลาง   ชาย   53                            (1)วิ่ง
# 4      2564  ภาคกลาง   ชาย   57                     (1)ปั่นจักรยาน
# 5      2564  ภาคกลาง  หญิง   55                            (1)โยคะ
# 7      2564  ภาคกลาง   ชาย   49  (1)การออกกำลังกายในการประกอบอาชีพ
# ...     ...      ...   ...  ...                                ...
# 20093  2565   ภาคใต้  หญิง   48                    (1)เดิน,(2)วิ่ง
# 20094  2565   ภาคใต้   ชาย   29                  (1)เดิน,(2)ฟุตบอล
# 20095  2565   ภาคใต้   ชาย   40          (1)เดิน,(2)วิ่ง,(3)ฟุตบอล
# 20096  2565   ภาคใต้   ชาย   35                            (1)เดิน
# 20097  2565   ภาคใต้  หญิง   35                      (1)วอลเลย์บอล
#
#                                             เหตุผล (ออก)  \
# 0      ต้องการให้ร่างกายแข็งแรง,ต้องการรูปร่างที่ดี/ห...
# ...

# %%
association = associate[associate['เหตุผล (ออก)'] !='-']
association
# Out:
#          ปี      ภาค   เพศ อายุ                            กิจกรรม  \
# 0      2564  ภาคกลาง  หญิง   55                     (1)ปั่นจักรยาน
# 3      2564  ภาคกลาง   ชาย   53                            (1)วิ่ง
# 4      2564  ภาคกลาง   ชาย   57                     (1)ปั่นจักรยาน
# 5      2564  ภาคกลาง  หญิง   55                            (1)โยคะ
# 7      2564  ภาคกลาง   ชาย   49  (1)การออกกำลังกายในการประกอบอาชีพ
# ...     ...      ...   ...  ...                                ...
# 20093  2565   ภาคใต้  หญิง   48                    (1)เดิน,(2)วิ่ง
# 20094  2565   ภาคใต้   ชาย   29                  (1)เดิน,(2)ฟุตบอล
# 20095  2565   ภาคใต้   ชาย   40          (1)เดิน,(2)วิ่ง,(3)ฟุตบอล
# 20096  2565   ภาคใต้   ชาย   35                            (1)เดิน
# 20097  2565   ภาคใต้  หญิง   35                      (1)วอลเลย์บอล
#
#                                             เหตุผล (ออก)  \
# 0      ต้องการให้ร่างกายแข็งแรง,ต้องการรูปร่างที่ดี/ห...
# ...

# %%
asslist = associate['เหตุผล (ออก)'].str.split(',', expand=True)
asslist
# Out:
#                                      0                                 1   \
# 0              ต้องการให้ร่างกายแข็งแรง        ต้องการรูปร่างที่ดี/หุ่นดี
# 3              ต้องการให้ร่างกายแข็งแรง           ควบคุมน้ำหนัก/ลดน้ำหนัก
# 4              ต้องการให้ร่างกายแข็งแรง         รักษา/บรรเทาอาการเจ็บป่วย
# 5                    คลายเครียด/พักผ่อน                              None
# 7               เป็นงานต้องทำ/เป็นอาชีพ                              None
# ...                                 ...                               ...
# 20093  ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน                              None
# 20094          ต้องการให้ร่างกายแข็งแรง                              None
# 20095  ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน        ใช้เวลาว่างให้เป็นประโยชน์
# 20096          ต้องการให้ร่างกายแข็งแรง  ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน
# 20097  ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน                              None
#
#                             2                   3                4   \
# ...

# %%
association = associate[associate['เหตุผล (ออก)'] !='-']
association
# Out:
#          ปี      ภาค   เพศ อายุ                            กิจกรรม  \
# 0      2564  ภาคกลาง  หญิง   55                     (1)ปั่นจักรยาน
# 3      2564  ภาคกลาง   ชาย   53                            (1)วิ่ง
# 4      2564  ภาคกลาง   ชาย   57                     (1)ปั่นจักรยาน
# 5      2564  ภาคกลาง  หญิง   55                            (1)โยคะ
# 7      2564  ภาคกลาง   ชาย   49  (1)การออกกำลังกายในการประกอบอาชีพ
# ...     ...      ...   ...  ...                                ...
# 20093  2565   ภาคใต้  หญิง   48                    (1)เดิน,(2)วิ่ง
# 20094  2565   ภาคใต้   ชาย   29                  (1)เดิน,(2)ฟุตบอล
# 20095  2565   ภาคใต้   ชาย   40          (1)เดิน,(2)วิ่ง,(3)ฟุตบอล
# 20096  2565   ภาคใต้   ชาย   35                            (1)เดิน
# 20097  2565   ภาคใต้  หญิง   35                      (1)วอลเลย์บอล
#
#                                             เหตุผล (ออก)  \
# 0      ต้องการให้ร่างกายแข็งแรง,ต้องการรูปร่างที่ดี/ห...
# ...

# %%
ass_s1 = association['กิจกรรม'].str.split(',', expand=False)
ass_s1
# Out:
# 0                           [(1)ปั่นจักรยาน]
# 3                                  [(1)วิ่ง]
# 4                           [(1)ปั่นจักรยาน]
# 5                                  [(1)โยคะ]
# 7        [(1)การออกกำลังกายในการประกอบอาชีพ]
#                         ...
# 20093                     [(1)เดิน, (2)วิ่ง]
# 20094                   [(1)เดิน, (2)ฟุตบอล]
# 20095          [(1)เดิน, (2)วิ่ง, (3)ฟุตบอล]
# 20096                              [(1)เดิน]
# 20097                        [(1)วอลเลย์บอล]
# Name: กิจกรรม, Length: 15501, dtype: object

# %%
h = asslist[0].str.split(',', expand=False)
h1 = h.dropna()
h2 = h1.apply(list)
h3 = list(filter(lambda x: x is not None, h2))

# %%
df = pd.DataFrame(h3)
df
# Out:
#                                       0
# 0              ต้องการให้ร่างกายแข็งแรง
# 1              ต้องการให้ร่างกายแข็งแรง
# 2              ต้องการให้ร่างกายแข็งแรง
# 3                    คลายเครียด/พักผ่อน
# 4               เป็นงานต้องทำ/เป็นอาชีพ
# ...                                 ...
# 15496  ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน
# 15497          ต้องการให้ร่างกายแข็งแรง
# 15498  ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน
# 15499          ต้องการให้ร่างกายแข็งแรง
# 15500  ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน
#
# [15501 rows x 1 columns]

# %%
associate['เหตุผล (ออก)'] = df[0]
associate
# Out:
# <ipython-input-125-ddb0c654c5c8>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   associate['เหตุผล (ออก)'] = df[0]
#          ปี      ภาค   เพศ อายุ                            กิจกรรม  \
# 0      2564  ภาคกลาง  หญิง   55                     (1)ปั่นจักรยาน
# 3      2564  ภาคกลาง   ชาย   53                            (1)วิ่ง
# 4      2564  ภาคกลาง   ชาย   57                     (1)ปั่นจักรยาน
# 5      2564  ภาคกลาง  หญิง   55                            (1)โยคะ
# 7      2564  ภาคกลาง   ชาย   49  (1)การออกกำลังกายในการประกอบอาชีพ
# ...     ...      ...   ...  ...                                ...
# 20093  2565   ภาคใต้  หญิง   48                    (1)เดิน,(2)วิ่ง
# 20094  2565   ภาคใต้   ชาย   29                  (1)เดิน,(2)ฟุตบอล
# ...

# %%
ass_s2 = associate['เวลา'].str.split(',', expand=True)
ass_s2
# Out:
#                        0                   1                   2     3     4   \
# 0      (06.00 - 07.00 น.)  (18.00 - 19.00 น.)                None  None  None
# 3      (06.00 - 07.00 น.)  (18.00 - 19.00 น.)                None  None  None
# 4      (07.00 - 08.00 น.)  (18.00 - 19.00 น.)                None  None  None
# 5      (16.00 - 17.00 น.)                None                None  None  None
# 7      (09.00 - 10.00 น.)  (18.00 - 19.00 น.)                None  None  None
# ...                   ...                 ...                 ...   ...   ...
# 20093  (05.00 - 06.00 น.)  (16.00 - 17.00 น.)                None  None  None
# 20094  (05.00 - 06.00 น.)  (16.00 - 17.00 น.)                None  None  None
# 20095  (05.00 - 06.00 น.)  (16.00 - 17.00 น.)  (17.00 - 18.00 น.)  None  None
# 20096  (05.00 - 06.00 น.)  (16.00 - 17.00 น.)  (17.00 - 18.00 น.)  None  None
# 20097  (16.00 - 17.00 น.)                None                None  None  None
#
# ...

# %%
associate['เวลา'] = ass_s2[0]
associate
# Out:
# <ipython-input-127-7d79cfea0792>:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   associate['เวลา'] = ass_s2[0]
#          ปี      ภาค   เพศ อายุ                            กิจกรรม  \
# 0      2564  ภาคกลาง  หญิง   55                     (1)ปั่นจักรยาน
# 3      2564  ภาคกลาง   ชาย   53                            (1)วิ่ง
# 4      2564  ภาคกลาง   ชาย   57                     (1)ปั่นจักรยาน
# 5      2564  ภาคกลาง  หญิง   55                            (1)โยคะ
# 7      2564  ภาคกลาง   ชาย   49  (1)การออกกำลังกายในการประกอบอาชีพ
# ...     ...      ...   ...  ...                                ...
# 20093  2565   ภาคใต้  หญิง   48                    (1)เดิน,(2)วิ่ง
# 20094  2565   ภาคใต้   ชาย   29                  (1)เดิน,(2)ฟุตบอล
# ...

# %%
a= associate.replace({'(05.00 - 06.00 น.)' : 'เช้า'})
b= a.replace({'(07.00 - 08.00 น.)' : 'เช้า'})
c=b.replace({'(06.00 - 07.00 น.)' : 'เช้า'})
d = c.replace({'(08.00 - 09.00 น.)' : 'เช้า'})
e  = d.replace({'(09.00 - 10.00 น.)' : 'เที่ยง'})
f=e.replace({'(10.00 - 11.00 น.)' : 'เที่ยง'})
i =f.replace({'(11.00 - 12.00 น.)' : 'เที่ยง'})
j =i.replace({'(12.00 - 13.00 น.)' : 'เที่ยง'})
k =j.replace({'(12.00 - 13.00 น.)' : 'เที่ยง'})
l =k.replace({'(13.00 - 14.00 น.)' : 'บ่าย'})
m =l.replace({'(14.00 - 15.00 น.)' : 'บ่าย'})
n =m.replace({'(15.00 - 16.00 น.)' : 'บ่าย'})
o =n.replace({'(16.00 - 17.00 น.)' : 'บ่าย'})
p =o.replace({'(17.00 - 18.00 น.)' : 'เย็น'})
q =p.replace({'(18.00 - 19.00 น.)' : 'เย็น'})
r =q.replace({'(19.00 - 20.00 น.)' : 'เย็น'})
aa = r.replace({'(20.00 - 21.00 น.)' : 'เย็น'})
bb =aa.replace({'(21.00 - 22.00 น.)' : 'ค่ำ'})
cc =bb.replace({'(22.00 - 23.00 น.)' : 'ค่ำ'})
dd =cc.replace({'(23.00 - 24.00 น.)' : 'ค่ำ'})
ee =dd.replace({'(00.00 - 01.00 น.)' : 'ค่ำ'})
ff =ee.replace({'(01.00 - 02.00 น.)' : 'ดึก'})
ii =ff.replace({'(02.00 - 03.00 น.)' : 'ดึก'})
jj=ii.replace({'(03.00 - 04.00 น.)' : 'ดึก'})
kk=jj.replace({'(04.00 - 05.00 น.)' : 'ดึก'})
kk
# Out:
#          ปี      ภาค   เพศ อายุ                            กิจกรรม  \
# 0      2564  ภาคกลาง  หญิง   55                     (1)ปั่นจักรยาน
# 3      2564  ภาคกลาง   ชาย   53                            (1)วิ่ง
# 4      2564  ภาคกลาง   ชาย   57                     (1)ปั่นจักรยาน
# 5      2564  ภาคกลาง  หญิง   55                            (1)โยคะ
# 7      2564  ภาคกลาง   ชาย   49  (1)การออกกำลังกายในการประกอบอาชีพ
# ...     ...      ...   ...  ...                                ...
# 20093  2565   ภาคใต้  หญิง   48                    (1)เดิน,(2)วิ่ง
# 20094  2565   ภาคใต้   ชาย   29                  (1)เดิน,(2)ฟุตบอล
# 20095  2565   ภาคใต้   ชาย   40          (1)เดิน,(2)วิ่ง,(3)ฟุตบอล
# 20096  2565   ภาคใต้   ชาย   35                            (1)เดิน
# 20097  2565   ภาคใต้  หญิง   35                      (1)วอลเลย์บอล
#
#                    เหตุผล (ออก)    เวลา
# 0      ต้องการให้ร่างกายแข็งแรง    เช้า
# 3            คลายเครียด/พักผ่อน    เช้า
# ...

# %%
jaa = kk.replace({'-' : np.NaN})
jaa.dropna()
# Out:
#          ปี      ภาค   เพศ  อายุ                            กิจกรรม  \
# 0      2564  ภาคกลาง  หญิง  55.0                     (1)ปั่นจักรยาน
# 3      2564  ภาคกลาง   ชาย  53.0                            (1)วิ่ง
# 4      2564  ภาคกลาง   ชาย  57.0                     (1)ปั่นจักรยาน
# 5      2564  ภาคกลาง  หญิง  55.0                            (1)โยคะ
# 7      2564  ภาคกลาง   ชาย  49.0  (1)การออกกำลังกายในการประกอบอาชีพ
# ...     ...      ...   ...   ...                                ...
# 15496  2565  ภาคกลาง  หญิง  20.0                     (1)ปั่นจักรยาน
# 15497  2565  ภาคกลาง  หญิง  50.0                            (1)เดิน
# 15498  2565  ภาคกลาง   ชาย  52.0                            (1)เดิน
# 15499  2565  ภาคกลาง  หญิง  25.0                     (1)เวทเทรนนิ่ง
# 15500  2565  ภาคกลาง   ชาย  36.0                          (1)ฟุตบอล
#
#                            เหตุผล (ออก)    เวลา
# 0              ต้องการให้ร่างกายแข็งแรง    เช้า
# 3                    คลายเครียด/พักผ่อน    เช้า
# ...

# %%
# !pip install apyori
from apyori import apriori
from mlxtend.frequent_patterns import apriori
from mlxtend.frequent_patterns import association_rules

# %% [markdown]
# ##เพศกับเหตุผล

# %%
ex = pd.get_dummies(jaa[['เพศ','เหตุผล (ออก)']])
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)

# %%
ex
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        เพศ_ชาย  เพศ_หญิง  เหตุผล (ออก)_ -  \
# 0            0         1                0
# 3            1         0                0
# 4            1         0                0
# 5            0         1                0
# 7            1         0                0
# ...        ...       ...              ...
# 20093        0         1                0
# 20094        1         0                0
# 20095        1         0                0
# 20096        1         0                0
# 20097        0         1                0
#
#        เหตุผล (ออก)_กำลังเป็นที่นิยม/ตามกระแสนิยม  \
# 0                                               0
# ...

# %%
# Apply Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(ex.iloc[:, 1:], min_support=0.002, use_colnames=True)

# Generate association rules
rules1 = association_rules(frequent_itemsets, metric="confidence",min_threshold=0.0001)

# Display frequent itemsets and association rules
print("Frequent Itemsets:")
print(frequent_itemsets)
print("\nAssociation Rules:")
rules1
# Out:
# Frequent Itemsets:
#      support                                           itemsets
# 0   0.512354                                         (เพศ_หญิง)
# 1   0.011483                  (เหตุผล (ออก)_คลายเครียด/พักผ่อน)
# 2   0.008580             (เหตุผล (ออก)_ควบคุมน้ำหนัก/ลดน้ำหนัก)
# 3   0.008903                      (เหตุผล (ออก)_ชอบออกกำลังกาย)
# 4   0.005742                     (เหตุผล (ออก)_ชอบในกีฬานั้น ๆ)
# 5   0.006580          (เหตุผล (ออก)_ต้องการรูปร่างที่ดี/หุ่นดี)
# 6   0.606993            (เหตุผล (ออก)_ต้องการให้ร่างกายแข็งแรง)
# 7   0.031030    (เหตุผล (ออก)_ทำกิจกรรมร่วมกับเพื่อน/เพื่อนชวน)
# 8   0.012193           (เหตุผล (ออก)_รักษา/บรรเทาอาการเจ็บป่วย)
# 9   0.035998             (เหตุผล (ออก)_เป็นงานต้องทำ/เป็นอาชีพ)
# 10  0.032514          (เหตุผล (ออก)_ใช้เวลาว่างให้เป็นประโยชน์)
# 11  0.006258        (เหตุผล (ออก)_คลายเครียด/พักผ่อน, เพศ_หญิง)
# 12  0.004516   (เพศ_หญิง, เหตุผล (ออก)_ควบคุมน้ำหนัก/ลดน้ำหนัก)
# ...

# %% [markdown]
# ##เพศกับกิจกรรม

# %%
ex1 = pd.get_dummies(jaa[['เพศ','กิจกรรม']])
ex1
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
#        เพศ_ชาย  เพศ_หญิง  กิจกรรม_ -  กิจกรรม_(1)กระโดดเชือก  \
# 0            0         1           0                       0
# 3            1         0           0                       0
# 4            1         0           0                       0
# 5            0         1           0                       0
# 7            1         0           0                       0
# ...        ...       ...         ...                     ...
# 20093        0         1           0                       0
# 20094        1         0           0                       0
# 20095        1         0           0                       0
# ...

# %%
# Apply Apriori algorithm to find frequent itemsets
frequent_itemsets = apriori(ex1.iloc[:, 1:], min_support=0.002, use_colnames=True)

# Generate association rules
rules2 = association_rules(frequent_itemsets, metric="confidence",min_threshold=0.0001)

# Display frequent itemsets and association rules
print("Frequent Itemsets:")
print(frequent_itemsets)
print("\nAssociation Rules:")
rules2
# Out:
# /usr/local/lib/python3.10/dist-packages/ipykernel/ipkernel.py:283: DeprecationWarning: `should_run_async` will not call `transform_cell` automatically in the future. Please pass the result to `transformed_cell` argument and any exception that happen during thetransform in `preprocessing_exc_tuple` in IPython 7.17 and above.
#   and should_run_async(code)
# /usr/local/lib/python3.10/dist-packages/mlxtend/frequent_patterns/fpcommon.py:110: DeprecationWarning: DataFrames with non-bool types result in worse computationalperformance and their support might be discontinued in the future.Please use a DataFrame with bool type
#   warnings.warn(
# Frequent Itemsets:
#      support                                           itemsets
# 0   0.512354                                         (เพศ_หญิง)
# 1   0.003742                           (กิจกรรม_(1)กระโดดเชือก)
# 2   0.034901        (กิจกรรม_(1)การออกกำลังกายในการประกอบอาชีพ)
# 3   0.002774                             (กิจกรรม_(1)บาสเกตบอล)
# ...
